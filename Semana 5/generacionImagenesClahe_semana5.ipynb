# %%
import os
import cv2
from tqdm import tqdm

# %%
# =====================================================
# DIRECTORIOS
# =====================================================

#INPUT_DIR  = "dataset/Training_LR_escala4"
#OUTPUT_DIR = "dataset/CLAHE/Training_CLAHE_escala4"
INPUT_DIR  = "dataset/Testing_LR_CLAHE_escala4"
OUTPUT_DIR = "dataset/CLAHE/Testing_CLAHE_escala4"
os.makedirs(OUTPUT_DIR, exist_ok=True)

# %%
# =====================================================
# PIPELINE
# =====================================================

def pipeline_correcto(imagen_lr,
                      clip_limit=2.0,
                      tile_grid_size=(8,8)):

    # Paso 1: Eliminación de ruido
    img_denoised = cv2.fastNlMeansDenoising(
        imagen_lr,
        h=10,
        templateWindowSize=7,
        searchWindowSize=21
    )

    # Paso 2: CLAHE
    clahe = cv2.createCLAHE(
        clipLimit=clip_limit,
        tileGridSize=tile_grid_size
    )

    img_clahe = clahe.apply(img_denoised)

    return img_denoised, img_clahe

# %%
# =====================================================
# BUSCAR IMÁGENES
# =====================================================

imagenes = []

for root, dirs, files in os.walk(INPUT_DIR):

    for file in files:

        if file.lower().endswith(".png"):

            imagenes.append(
                os.path.join(root, file)
            )

print(f"Imágenes encontradas: {len(imagenes)}")
# Out:
# Imágenes encontradas: 40

# %%
# =====================================================
# GENERAR DATASET CLAHE en escala x4
# =====================================================

for ruta_img in tqdm(imagenes):

    img = cv2.imread(
        ruta_img,
        cv2.IMREAD_GRAYSCALE
    )

    if img is None:
        continue

    _, img_clahe = pipeline_correcto(img)

    # Mantener estructura s1,s2,...
    relative_path = os.path.relpath(
        ruta_img,
        INPUT_DIR
    )

    save_path = os.path.join(
        OUTPUT_DIR,
        relative_path
    )

    os.makedirs(
        os.path.dirname(save_path),
        exist_ok=True
    )

    cv2.imwrite(
        save_path,
        img_clahe
    )

print("\nDataset CLAHE escala x4 generado correctamente.")
print(f"Total imágenes: {len(imagenes)}")
print(f"Guardado en: {OUTPUT_DIR}")
# Out:
# 100%|██████████| 40/40 [00:02<00:00, 19.73it/s]
# Dataset CLAHE escala x4 generado correctamente.
# Total imágenes: 40
# Guardado en: dataset/CLAHE/Testing_CLAHE_escala4
